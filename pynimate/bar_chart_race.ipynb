# %%
from matplotlib import pyplot as plt
import pandas as pd
import pynimate as nim

# sample data
df = pd.DataFrame(
    {
        "time": ["1960-01-01", "1961-01-01", "1962-01-01"],
        "Afghanistan": [1, 2, 3],
        "Angola": [2, 3, 4],
        "Albania": [1, 2, 5],
        "USA": [5, 3, 4],
        "Argentina": [1, 4, 5],
    }
).set_index("time")

# a Canvas object is created using pynimate.
cnv = nim.Canvas()

# %%
# A Barplot object is created using the DataFrame df, 
# specifying the format of the dates in the time column as "%Y-%m-%d", 
# and the dimension of the plot as "2d". 
bar = nim.Barplot(df, "%Y-%m-%d", "2d")

# %%
bar.set_time(callback=lambda i, datafier: datafier.data.index[i].strftime("%b, %Y"))
print(dir(bar))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_get_rounded_eges', 'add_extras', 'add_var', 'annot_bars', 'ax', 'bar_annot_props', 'bar_border_props', 'barh_props', 'datafier', 'extra_callbacks', 'fixed_xlim', 'getTopXY', 'grid', 'grid_behind', 'grid_props', 'init', 'length', 'n_bars', 'post_update', 'remove_text', 'rounded_edges', 'set_axes', 'set_bar_annots', 'set_bar_border_props', 'set_bar_color', 'set_barh', 'set_grid', 'set_text', 'set_time', 'set_title', 'set_xlabel', 'set_xticks', 'set_xylim', 'set_yticks', 'text_collection', 'time_range', 'total_max', 'update', 'xlim', 'xtick_props', 'xticks', 'ylim', 'ytick_props', 'yticks']

# %%
bar.time_range
# Out:
# [Timestamp('1960-01-01 00:00:00'),
#  Timestamp('1960-01-03 00:00:00'),
#  Timestamp('1960-01-05 00:00:00'),
#  Timestamp('1960-01-07 00:00:00'),
#  Timestamp('1960-01-09 00:00:00'),
#  Timestamp('1960-01-11 00:00:00'),
#  Timestamp('1960-01-13 00:00:00'),
#  Timestamp('1960-01-15 00:00:00'),
#  Timestamp('1960-01-17 00:00:00'),
#  Timestamp('1960-01-19 00:00:00'),
#  Timestamp('1960-01-21 00:00:00'),
#  Timestamp('1960-01-23 00:00:00'),
#  Timestamp('1960-01-25 00:00:00'),
#  Timestamp('1960-01-27 00:00:00'),
#  Timestamp('1960-01-29 00:00:00'),
#  Timestamp('1960-01-31 00:00:00'),
#  Timestamp('1960-02-02 00:00:00'),
#  Timestamp('1960-02-04 00:00:00'),
#  Timestamp('1960-02-06 00:00:00'),
#  Timestamp('1960-02-08 00:00:00'),
#  Timestamp('1960-02-10 00:00:00'),
#  Timestamp('1960-02-12 00:00:00'),
#  Timestamp('1960-02-14 00:00:00'),
#  Timestamp('1960-02-16 00:00:00'),
#  Timestamp('1960-02-18 00:00:00'),
#  Timestamp('1960-02-20 00:00:00'),
#  Timestamp('1960-02-22 00:00:00'),
#  Timestamp('1960-02-24 00:00:00'),
#  Timestamp('1960-02-26 00:00:00'),
#  Timestamp('1960-02-28 00:00:00'),
#  Timestamp('1960-03-01 00:00:00'),
#  Timestamp('1960-03-03 00:00:00'),
#  Timestamp('1960-03-05 00:00:00'),
#  Timestamp('1960-03-07 00:00:00'),
#  Timestamp('1960-03-09 00:00:00'),
#  Timestamp('1960-03-11 00:00:00'),
#  Timestamp('1960-03-13 00:00:00'),
#  Timestamp('1960-03-15 00:00:00'),
#  Timestamp('1960-03-17 00:00:00'),
#  Timestamp('1960-03-19 00:00:00'),
#  Timestamp('1960-03-21 00:00:00'),
#  Timestamp('1960-03-23 00:00:00'),
#  Timestamp('1960-03-25 00:00:00'),
#  Timestamp('1960-03-27 00:00:00'),
#  Timestamp('1960-03-29 00:00:00'),
#  Timestamp('1960-03-31 00:00:00'),
#  Timestamp('1960-04-02 00:00:00'),
#  Timestamp('1960-04-04 00:00:00'),
#  Timestamp('1960-04-06 00:00:00'),
#  Timestamp('1960-04-08 00:00:00'),
#  Timestamp('1960-04-10 00:00:00'),
#  Timestamp('1960-04-12 00:00:00'),
#  Timestamp('1960-04-14 00:00:00'),
#  Timestamp('1960-04-16 00:00:00'),
#  Timestamp('1960-04-18 00:00:00'),
#  Timestamp('1960-04-20 00:00:00'),
#  Timestamp('1960-04-22 00:00:00'),
#  Timestamp('1960-04-24 00:00:00'),
#  Timestamp('1960-04-26 00:00:00'),
#  Timestamp('1960-04-28 00:00:00'),
#  Timestamp('1960-04-30 00:00:00'),
#  Timestamp('1960-05-02 00:00:00'),
#  Timestamp('1960-05-04 00:00:00'),
#  Timestamp('1960-05-06 00:00:00'),
#  Timestamp('1960-05-08 00:00:00'),
#  Timestamp('1960-05-10 00:00:00'),
#  Timestamp('1960-05-12 00:00:00'),
#  Timestamp('1960-05-14 00:00:00'),
#  Timestamp('1960-05-16 00:00:00'),
#  Timestamp('1960-05-18 00:00:00'),
#  Timestamp('1960-05-20 00:00:00'),
#  Timestamp('1960-05-22 00:00:00'),
#  Timestamp('1960-05-24 00:00:00'),
#  Timestamp('1960-05-26 00:00:00'),
#  Timestamp('1960-05-28 00:00:00'),
#  Timestamp('1960-05-30 00:00:00'),
#  Timestamp('1960-06-01 00:00:00'),
#  Timestamp('1960-06-03 00:00:00'),
#  Timestamp('1960-06-05 00:00:00'),
#  Timestamp('1960-06-07 00:00:00'),
#  Timestamp('1960-06-09 00:00:00'),
#  Timestamp('1960-06-11 00:00:00'),
#  Timestamp('1960-06-13 00:00:00'),
#  Timestamp('1960-06-15 00:00:00'),
#  Timestamp('1960-06-17 00:00:00'),
#  Timestamp('1960-06-19 00:00:00'),
#  Timestamp('1960-06-21 00:00:00'),
#  Timestamp('1960-06-23 00:00:00'),
#  Timestamp('1960-06-25 00:00:00'),
#  Timestamp('1960-06-27 00:00:00'),
#  Timestamp('1960-06-29 00:00:00'),
#  Timestamp('1960-07-01 00:00:00'),
#  Timestamp('1960-07-03 00:00:00'),
#  Timestamp('1960-07-05 00:00:00'),
#  Timestamp('1960-07-07 00:00:00'),
#  Timestamp('1960-07-09 00:00:00'),
#  Timestamp('1960-07-11 00:00:00'),
#  Timestamp('1960-07-13 00:00:00'),
#  Timestamp('1960-07-15 00:00:00'),
#  Timestamp('1960-07-17 00:00:00'),
#  Timestamp('1960-07-19 00:00:00'),
#  Timestamp('1960-07-21 00:00:00'),
#  Timestamp('1960-07-23 00:00:00'),
#  Timestamp('1960-07-25 00:00:00'),
#  Timestamp('1960-07-27 00:00:00'),
#  Timestamp('1960-07-29 00:00:00'),
#  Timestamp('1960-07-31 00:00:00'),
#  Timestamp('1960-08-02 00:00:00'),
#  Timestamp('1960-08-04 00:00:00'),
#  Timestamp('1960-08-06 00:00:00'),
#  Timestamp('1960-08-08 00:00:00'),
#  Timestamp('1960-08-10 00:00:00'),
#  Timestamp('1960-08-12 00:00:00'),
#  Timestamp('1960-08-14 00:00:00'),
#  Timestamp('1960-08-16 00:00:00'),
#  Timestamp('1960-08-18 00:00:00'),
#  Timestamp('1960-08-20 00:00:00'),
#  Timestamp('1960-08-22 00:00:00'),
#  Timestamp('1960-08-24 00:00:00'),
#  Timestamp('1960-08-26 00:00:00'),
#  Timestamp('1960-08-28 00:00:00'),
#  Timestamp('1960-08-30 00:00:00'),
#  Timestamp('1960-09-01 00:00:00'),
#  Timestamp('1960-09-03 00:00:00'),
#  Timestamp('1960-09-05 00:00:00'),
#  Timestamp('1960-09-07 00:00:00'),
#  Timestamp('1960-09-09 00:00:00'),
#  Timestamp('1960-09-11 00:00:00'),
#  Timestamp('1960-09-13 00:00:00'),
#  Timestamp('1960-09-15 00:00:00'),
#  Timestamp('1960-09-17 00:00:00'),
#  Timestamp('1960-09-19 00:00:00'),
#  Timestamp('1960-09-21 00:00:00'),
#  Timestamp('1960-09-23 00:00:00'),
#  Timestamp('1960-09-25 00:00:00'),
#  Timestamp('1960-09-27 00:00:00'),
#  Timestamp('1960-09-29 00:00:00'),
#  Timestamp('1960-10-01 00:00:00'),
#  Timestamp('1960-10-03 00:00:00'),
#  Timestamp('1960-10-05 00:00:00'),
#  Timestamp('1960-10-07 00:00:00'),
#  Timestamp('1960-10-09 00:00:00'),
#  Timestamp('1960-10-11 00:00:00'),
#  Timestamp('1960-10-13 00:00:00'),
#  Timestamp('1960-10-15 00:00:00'),
#  Timestamp('1960-10-17 00:00:00'),
#  Timestamp('1960-10-19 00:00:00'),
#  Timestamp('1960-10-21 00:00:00'),
#  Timestamp('1960-10-23 00:00:00'),
#  Timestamp('1960-10-25 00:00:00'),
#  Timestamp('1960-10-27 00:00:00'),
#  Timestamp('1960-10-29 00:00:00'),
#  Timestamp('1960-10-31 00:00:00'),
#  Timestamp('1960-11-02 00:00:00'),
#  Timestamp('1960-11-04 00:00:00'),
#  Timestamp('1960-11-06 00:00:00'),
#  Timestamp('1960-11-08 00:00:00'),
#  Timestamp('1960-11-10 00:00:00'),
#  Timestamp('1960-11-12 00:00:00'),
#  Timestamp('1960-11-14 00:00:00'),
#  Timestamp('1960-11-16 00:00:00'),
#  Timestamp('1960-11-18 00:00:00'),
#  Timestamp('1960-11-20 00:00:00'),
#  Timestamp('1960-11-22 00:00:00'),
#  Timestamp('1960-11-24 00:00:00'),
#  Timestamp('1960-11-26 00:00:00'),
#  Timestamp('1960-11-28 00:00:00'),
#  Timestamp('1960-11-30 00:00:00'),
#  Timestamp('1960-12-02 00:00:00'),
#  Timestamp('1960-12-04 00:00:00'),
#  Timestamp('1960-12-06 00:00:00'),
#  Timestamp('1960-12-08 00:00:00'),
#  Timestamp('1960-12-10 00:00:00'),
#  Timestamp('1960-12-12 00:00:00'),
#  Timestamp('1960-12-14 00:00:00'),
#  Timestamp('1960-12-16 00:00:00'),
#  Timestamp('1960-12-18 00:00:00'),
#  Timestamp('1960-12-20 00:00:00'),
#  Timestamp('1960-12-22 00:00:00'),
#  Timestamp('1960-12-24 00:00:00'),
#  Timestamp('1960-12-26 00:00:00'),
#  Timestamp('1960-12-28 00:00:00'),
#  Timestamp('1960-12-30 00:00:00'),
#  Timestamp('1961-01-01 00:00:00'),
#  Timestamp('1961-01-03 00:00:00'),
#  Timestamp('1961-01-05 00:00:00'),
#  Timestamp('1961-01-07 00:00:00'),
#  Timestamp('1961-01-09 00:00:00'),
#  Timestamp('1961-01-11 00:00:00'),
#  Timestamp('1961-01-13 00:00:00'),
#  Timestamp('1961-01-15 00:00:00'),
#  Timestamp('1961-01-17 00:00:00'),
#  Timestamp('1961-01-19 00:00:00'),
#  Timestamp('1961-01-21 00:00:00'),
#  Timestamp('1961-01-23 00:00:00'),
#  Timestamp('1961-01-25 00:00:00'),
#  Timestamp('1961-01-27 00:00:00'),
#  Timestamp('1961-01-29 00:00:00'),
#  Timestamp('1961-01-31 00:00:00'),
#  Timestamp('1961-02-02 00:00:00'),
#  Timestamp('1961-02-04 00:00:00'),
#  Timestamp('1961-02-06 00:00:00'),
#  Timestamp('1961-02-08 00:00:00'),
#  Timestamp('1961-02-10 00:00:00'),
#  Timestamp('1961-02-12 00:00:00'),
#  Timestamp('1961-02-14 00:00:00'),
#  Timestamp('1961-02-16 00:00:00'),
#  Timestamp('1961-02-18 00:00:00'),
#  Timestamp('1961-02-20 00:00:00'),
#  Timestamp('1961-02-22 00:00:00'),
#  Timestamp('1961-02-24 00:00:00'),
#  Timestamp('1961-02-26 00:00:00'),
#  Timestamp('1961-02-28 00:00:00'),
#  Timestamp('1961-03-02 00:00:00'),
#  Timestamp('1961-03-04 00:00:00'),
#  Timestamp('1961-03-06 00:00:00'),
#  Timestamp('1961-03-08 00:00:00'),
#  Timestamp('1961-03-10 00:00:00'),
#  Timestamp('1961-03-12 00:00:00'),
#  Timestamp('1961-03-14 00:00:00'),
#  Timestamp('1961-03-16 00:00:00'),
#  Timestamp('1961-03-18 00:00:00'),
#  Timestamp('1961-03-20 00:00:00'),
#  Timestamp('1961-03-22 00:00:00'),
#  Timestamp('1961-03-24 00:00:00'),
#  Timestamp('1961-03-26 00:00:00'),
#  Timestamp('1961-03-28 00:00:00'),
#  Timestamp('1961-03-30 00:00:00'),
#  Timestamp('1961-04-01 00:00:00'),
#  Timestamp('1961-04-03 00:00:00'),
#  Timestamp('1961-04-05 00:00:00'),
#  Timestamp('1961-04-07 00:00:00'),
#  Timestamp('1961-04-09 00:00:00'),
#  Timestamp('1961-04-11 00:00:00'),
#  Timestamp('1961-04-13 00:00:00'),
#  Timestamp('1961-04-15 00:00:00'),
#  Timestamp('1961-04-17 00:00:00'),
#  Timestamp('1961-04-19 00:00:00'),
#  Timestamp('1961-04-21 00:00:00'),
#  Timestamp('1961-04-23 00:00:00'),
#  Timestamp('1961-04-25 00:00:00'),
#  Timestamp('1961-04-27 00:00:00'),
#  Timestamp('1961-04-29 00:00:00'),
#  Timestamp('1961-05-01 00:00:00'),
#  Timestamp('1961-05-03 00:00:00'),
#  Timestamp('1961-05-05 00:00:00'),
#  Timestamp('1961-05-07 00:00:00'),
#  Timestamp('1961-05-09 00:00:00'),
#  Timestamp('1961-05-11 00:00:00'),
#  Timestamp('1961-05-13 00:00:00'),
#  Timestamp('1961-05-15 00:00:00'),
#  Timestamp('1961-05-17 00:00:00'),
#  Timestamp('1961-05-19 00:00:00'),
#  Timestamp('1961-05-21 00:00:00'),
#  Timestamp('1961-05-23 00:00:00'),
#  Timestamp('1961-05-25 00:00:00'),
#  Timestamp('1961-05-27 00:00:00'),
#  Timestamp('1961-05-29 00:00:00'),
#  Timestamp('1961-05-31 00:00:00'),
#  Timestamp('1961-06-02 00:00:00'),
#  Timestamp('1961-06-04 00:00:00'),
#  Timestamp('1961-06-06 00:00:00'),
#  Timestamp('1961-06-08 00:00:00'),
#  Timestamp('1961-06-10 00:00:00'),
#  Timestamp('1961-06-12 00:00:00'),
#  Timestamp('1961-06-14 00:00:00'),
#  Timestamp('1961-06-16 00:00:00'),
#  Timestamp('1961-06-18 00:00:00'),
#  Timestamp('1961-06-20 00:00:00'),
#  Timestamp('1961-06-22 00:00:00'),
#  Timestamp('1961-06-24 00:00:00'),
#  Timestamp('1961-06-26 00:00:00'),
#  Timestamp('1961-06-28 00:00:00'),
#  Timestamp('1961-06-30 00:00:00'),
#  Timestamp('1961-07-02 00:00:00'),
#  Timestamp('1961-07-04 00:00:00'),
#  Timestamp('1961-07-06 00:00:00'),
#  Timestamp('1961-07-08 00:00:00'),
#  Timestamp('1961-07-10 00:00:00'),
#  Timestamp('1961-07-12 00:00:00'),
#  Timestamp('1961-07-14 00:00:00'),
#  Timestamp('1961-07-16 00:00:00'),
#  Timestamp('1961-07-18 00:00:00'),
#  Timestamp('1961-07-20 00:00:00'),
#  Timestamp('1961-07-22 00:00:00'),
#  Timestamp('1961-07-24 00:00:00'),
#  Timestamp('1961-07-26 00:00:00'),
#  Timestamp('1961-07-28 00:00:00'),
#  Timestamp('1961-07-30 00:00:00'),
#  Timestamp('1961-08-01 00:00:00'),
#  Timestamp('1961-08-03 00:00:00'),
#  Timestamp('1961-08-05 00:00:00'),
#  Timestamp('1961-08-07 00:00:00'),
#  Timestamp('1961-08-09 00:00:00'),
#  Timestamp('1961-08-11 00:00:00'),
#  Timestamp('1961-08-13 00:00:00'),
#  Timestamp('1961-08-15 00:00:00'),
#  Timestamp('1961-08-17 00:00:00'),
#  Timestamp('1961-08-19 00:00:00'),
#  Timestamp('1961-08-21 00:00:00'),
#  Timestamp('1961-08-23 00:00:00'),
#  Timestamp('1961-08-25 00:00:00'),
#  Timestamp('1961-08-27 00:00:00'),
#  Timestamp('1961-08-29 00:00:00'),
#  Timestamp('1961-08-31 00:00:00'),
#  Timestamp('1961-09-02 00:00:00'),
#  Timestamp('1961-09-04 00:00:00'),
#  Timestamp('1961-09-06 00:00:00'),
#  Timestamp('1961-09-08 00:00:00'),
#  Timestamp('1961-09-10 00:00:00'),
#  Timestamp('1961-09-12 00:00:00'),
#  Timestamp('1961-09-14 00:00:00'),
#  Timestamp('1961-09-16 00:00:00'),
#  Timestamp('1961-09-18 00:00:00'),
#  Timestamp('1961-09-20 00:00:00'),
#  Timestamp('1961-09-22 00:00:00'),
#  Timestamp('1961-09-24 00:00:00'),
#  Timestamp('1961-09-26 00:00:00'),
#  Timestamp('1961-09-28 00:00:00'),
#  Timestamp('1961-09-30 00:00:00'),
#  Timestamp('1961-10-02 00:00:00'),
#  Timestamp('1961-10-04 00:00:00'),
#  Timestamp('1961-10-06 00:00:00'),
#  Timestamp('1961-10-08 00:00:00'),
#  Timestamp('1961-10-10 00:00:00'),
#  Timestamp('1961-10-12 00:00:00'),
#  Timestamp('1961-10-14 00:00:00'),
#  Timestamp('1961-10-16 00:00:00'),
#  Timestamp('1961-10-18 00:00:00'),
#  Timestamp('1961-10-20 00:00:00'),
#  Timestamp('1961-10-22 00:00:00'),
#  Timestamp('1961-10-24 00:00:00'),
#  Timestamp('1961-10-26 00:00:00'),
#  Timestamp('1961-10-28 00:00:00'),
#  Timestamp('1961-10-30 00:00:00'),
#  Timestamp('1961-11-01 00:00:00'),
#  Timestamp('1961-11-03 00:00:00'),
#  Timestamp('1961-11-05 00:00:00'),
#  Timestamp('1961-11-07 00:00:00'),
#  Timestamp('1961-11-09 00:00:00'),
#  Timestamp('1961-11-11 00:00:00'),
#  Timestamp('1961-11-13 00:00:00'),
#  Timestamp('1961-11-15 00:00:00'),
#  Timestamp('1961-11-17 00:00:00'),
#  Timestamp('1961-11-19 00:00:00'),
#  Timestamp('1961-11-21 00:00:00'),
#  Timestamp('1961-11-23 00:00:00'),
#  Timestamp('1961-11-25 00:00:00'),
#  Timestamp('1961-11-27 00:00:00'),
#  Timestamp('1961-11-29 00:00:00'),
#  Timestamp('1961-12-01 00:00:00'),
#  Timestamp('1961-12-03 00:00:00'),
#  Timestamp('1961-12-05 00:00:00'),
#  Timestamp('1961-12-07 00:00:00'),
#  Timestamp('1961-12-09 00:00:00'),
#  Timestamp('1961-12-11 00:00:00'),
#  Timestamp('1961-12-13 00:00:00'),
#  Timestamp('1961-12-15 00:00:00'),
#  Timestamp('1961-12-17 00:00:00'),
#  Timestamp('1961-12-19 00:00:00'),
#  Timestamp('1961-12-21 00:00:00'),
#  Timestamp('1961-12-23 00:00:00'),
#  Timestamp('1961-12-25 00:00:00'),
#  Timestamp('1961-12-27 00:00:00'),
#  Timestamp('1961-12-29 00:00:00'),
#  Timestamp('1961-12-31 00:00:00'),
#  Timestamp('1962-01-01 00:00:00')]

# %%
bar.set_time(callback=lambda i, datafier: datafier.data.index[i].strftime("%b, %Y"))
cnv.add_plot(bar)
cnv.animate()
plt.show()

# %%
# Save the animation
cnv.save("file", 24, "gif")
cnv.save("file", 24 ,"mp4")

# %%
cnv.save("file2", 24 ,"mp4")
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\PIL\Image.py:2298, in Image.save(self, fp, format, **params)
#    2297 try:
# -> 2298     format = EXTENSION[ext]
#    2299 except KeyError as e:
#
# KeyError: '.mp4'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 cnv.save("file2", 24 ,"mp4")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pynimate\canvas.py:114, in Canvas.save(self, filename, fps, extension, **kwargs)
#     102 def save(self, filename: str, fps: int, extension: str = "gif", **kwargs):
#     103     """Saves the current animation
#     104
#     105     Parameters
#    (...)
#     112         File extension, by default "gif"
#     113     """
# --> 114     self.ani.save(f"{filename}.{extension}", fps=fps, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\animation.py:1071, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1065     _log.info("Disabling savefig.bbox = 'tight', as it may cause "
#    1066               "frame size to vary, which is inappropriate for "
#    1067               "animation.")
#    1068 # canvas._is_saving = True makes the draw_event animation-starting
#    1069 # callback a no-op; canvas.manager = None prevents resizing the GUI
#    1070 # widget (both are likewise done in savefig()).
# -> 1071 with mpl.rc_context({'savefig.bbox': None}), \
#    1072      writer.saving(self._fig, filename, dpi), \
#    1073      cbook._setattr_cm(self._fig.canvas,
#    1074                        _is_saving=True, manager=None):
#    1075     for anim in all_anim:
#    1076         anim._init_draw()  # Clear the initial frame
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\contextlib.py:142, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     140 if typ is None:
#     141     try:
# --> 142         next(self.gen)
#     143     except StopIteration:
#     144         return False
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\animation.py:236, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     234     yield self
#     235 finally:
# --> 236     self.finish()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\animation.py:512, in PillowWriter.finish(self)
#     511 def finish(self):
# --> 512     self._frames[0].save(
#     513         self.outfile, save_all=True, append_images=self._frames[1:],
#     514         duration=int(1000 / self.fps), loop=0)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\PIL\Image.py:2300, in Image.save(self, fp, format, **params)
#    2298         format = EXTENSION[ext]
#    2299     except KeyError as e:
# -> 2300         raise ValueError(f"unknown file extension: {ext}") from e
#    2302 if format.upper() not in SAVE:
#    2303     init()
#
# ValueError: unknown file extension: .mp4
